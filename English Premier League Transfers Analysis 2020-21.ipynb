# %%
#Importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(style="darkgrid")

# %%
#Importing the file
file = "https://raw.githubusercontent.com/ewenme/transfers/master/data/2020/english_premier_league.csv"

# %%
#Reading the file in pandas
df = pd.read_csv(file)
#Showing the first 5 rows
df.head()
# Out:
#     club_name           player_name  age            position  \
# 0  Arsenal FC         Thomas Partey   27  Defensive Midfield
# 1  Arsenal FC               Gabriel   22         Centre-Back
# 2  Arsenal FC            Pablo Marí   26         Centre-Back
# 3  Arsenal FC  Rúnar Alex Rúnarsson   25          Goalkeeper
# 4  Arsenal FC         Cédric Soares   28          Right-Back
#
#   club_involved_name            fee transfer_movement transfer_period  \
# 0    Atlético Madrid        £45.00m                in          Summer
# 1         LOSC Lille        £23.40m                in          Summer
# 2           Flamengo         £5.40m                in          Summer
# 3              Dijon         £1.80m                in          Summer
# 4        Southampton  free transfer                in          Summer
#
#    fee_cleaned     league_name  year     season
# 0         45.0  Premier League  2020  2020/2021
# 1         23.4  Premier League  2020  2020/2021
# 2          5.4  Premier League  2020  2020/2021
# 3          1.8  Premier League  2020  2020/2021
# 4          NaN  Premier League  2020  2020/2021

# %%
#Finding the total amount of money spent in EPL Transfers 2019/20
z = df['fee_cleaned'].sum()
print("A total of £{:.2f} million was spent in the EPL Transfers 2019/20 seaon".format(z))
# Out:
# A total of £1800.23 million was spent in the EPL Transfers 2019/20 seaon

# %%
#To shoe the matplotlib in the notebook itself
# %matplotlib inline
#Setting the size of the plot
plt.rcParams['figure.figsize']=30,15

# %%
#Finding the Number of Players sold Based on Position
a = df['position']
av = df['position'].value_counts()
a_dict = list(dict.fromkeys(a))
sns.countplot(x = "position",
              data = df,
              palette="autumn",
              order = df['position'].value_counts().index)
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(fontsize = 30,rotation = 60)
plt.yticks(fontsize = 30)
plt.xlabel("Position",fontsize = 35)
plt.ylabel("Number of players",fontsize = 35)
plt.title("Number of players sold based on position",fontsize = 50)
print(av)
# Out:
# Centre-Back           119
# Central Midfield      102
# Centre-Forward         93
# Goalkeeper             90
# Right Winger           59
# Right-Back             55
# Attacking Midfield     46
# Left Winger            42
# Left-Back              37
# Defensive Midfield     32
# Right Midfield         10
# Second Striker          7
# Left Midfield           1
# Name: position, dtype: int64

# %%
#Finding the Number of Players sold Based on Fee
b = df['fee_cleaned']
bv = df['fee_cleaned'].value_counts()
b_dict = list(dict.fromkeys(b))
plt.plot(bv,c ='Magenta' , ls='', marker = 'o', ms=15)
print(bv)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
plt.xlabel("Fee in £ (in million)",fontsize = 35)
plt.ylabel("Number of players",fontsize = 35)
plt.title("Number of players sold based on fee",fontsize = 50)
# Out:
# 0.00     282
# 1.80       9
# 0.99       9
# 0.90       6
# 5.85       6
#         ...
# 3.51       1
# 1.17       1
# 61.20      1
# 40.77      1
# 20.25      1
# Name: fee_cleaned, Length: 87, dtype: int64
# Text(0.5, 1.0, 'Number of players sold based on fee')

# %%
#Finding the Number of Players sold Based on Age
c = df['age']
cv = c.value_counts()
c_dict = list(dict.fromkeys(c))
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
sns.countplot(x = "age",
              data = df,
              palette= "Spectral",)
plt.show
plt.xticks(fontsize = 30,rotation = 0)
plt.yticks(fontsize = 30)
plt.xlabel("Age",fontsize = 35)
plt.ylabel("Number of players",fontsize = 35)
plt.title("Number of players sold based on age",fontsize = 50)
cv.head()
# Out:
# 23    92
# 22    62
# 21    62
# 24    55
# 25    53
# Name: age, dtype: int64

# %%
#Finding the Number of Players sold Based on the club that bought players
d = df['club_name']
dv = df['club_name'].value_counts()
d_dict = list(dict.fromkeys(d))
df.head()
sns.countplot(x = 'club_name',data = df,
              palette = 'Blues_r',
             order = df['club_name'].value_counts().index)
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.show
plt.xticks(fontsize = 30,rotation = 65)
plt.yticks(fontsize = 30)
plt.xlabel("Club Name",fontsize = 35)
plt.ylabel("Number of players",fontsize = 35)
plt.title("Club that bought players",fontsize = 50)
# Out:
# Text(0.5, 1.0, 'Club that bought players')

# %%
#Finding the Number of Players sold Based on Transfer movement
e = df['transfer_movement']
ev = df['transfer_movement'].value_counts()
e_dict = list(dict.fromkeys(c))
ev.plot(kind = 'bar',color = ['red','green'])
print(ev)
plt.show
plt.xticks(fontsize = 30,rotation = 0)
plt.yticks(fontsize = 30)
plt.xlabel("Transfer movement",fontsize = 35)
plt.ylabel("Number of players",fontsize = 35)
plt.title("Transfer movement",fontsize = 50)
# Out:
# in     352
# out    341
# Name: transfer_movement, dtype: int64
# Text(0.5, 1.0, 'Transfer movement')

# %%
#Finding the Number of Players sold Based on the club that sold players
f = df['club_involved_name'][:20]
fv = df['club_involved_name'].value_counts()[:20]
f_dict = list(dict.fromkeys(f))
sns.countplot(x = "club_involved_name",
              data = df,
              palette="hot",
              order = df['club_involved_name'].value_counts()[:20].index)
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.show
plt.xticks(fontsize = 30,rotation = 65)
plt.yticks(fontsize = 30)
plt.xlabel("Club Name",fontsize = 35)
plt.ylabel("Number of players",fontsize = 35)
plt.title("Club that sold players",fontsize = 50)
# Out:
# Text(0.5, 1.0, 'Club that sold players')

# %%
#Finding how many players were sold above £40 million
fdf = df[df['fee_cleaned']>=40]
fdf.shape
# Out:
# (10, 12)

# %%
#The name,fee,position and club that bought players above £40 million
adc = list(zip(fdf.player_name, fdf.fee_cleaned,fdf.position,fdf.club_name))
adc
# Out:
# [('Thomas Partey', 45.0, 'Defensive Midfield', 'Arsenal FC'),
#  ('Kai Havertz', 72.0, 'Attacking Midfield', 'Chelsea FC'),
#  ('Timo Werner', 47.7, 'Centre-Forward', 'Chelsea FC'),
#  ('Ben Chilwell', 45.18, 'Left-Back', 'Chelsea FC'),
#  ('Ben Chilwell', 45.18, 'Left-Back', 'Leicester City'),
#  ('Diogo Jota', 40.23, 'Left Winger', 'Liverpool FC'),
#  ('Rúben Dias', 61.2, 'Centre-Back', 'Manchester City'),
#  ('Nathan Aké', 40.77, 'Centre-Back', 'Manchester City'),
#  ('Leroy Sané', 54.0, 'Left Winger', 'Manchester City'),
#  ('Diogo Jota', 40.23, 'Left Winger', 'Wolverhampton Wanderers')]

# %%
tsdf = df[df['fee_cleaned']>=0].groupby(df['club_name']).sum()
tsdf.head()
# Out:
#                         age  fee_cleaned   year
# club_name
# Arsenal FC              439       94.635  36360
# Aston Villa             451       93.710  34340
# Brighton & Hove Albion  815       44.190  66660
# Burnley FC              204        3.060  16160
# Chelsea FC              846      274.140  68680

# %%
tsdf.index
# Out:
# Index(['Arsenal FC', 'Aston Villa', 'Brighton & Hove Albion', 'Burnley FC',
#        'Chelsea FC', 'Crystal Palace', 'Everton FC', 'Fulham FC',
#        'Leeds United', 'Leicester City', 'Liverpool FC', 'Manchester City',
#        'Manchester United', 'Newcastle United', 'Sheffield United',
#        'Southampton FC', 'Tottenham Hotspur', 'West Bromwich Albion',
#        'West Ham United', 'Wolverhampton Wanderers'],
#       dtype='object', name='club_name')

# %%
#How much money each club spent 
sns.barplot(x=tsdf.index,
            y="fee_cleaned",
            data=tsdf,
            palette="rocket",)
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(fontsize = 30,rotation = 65)
plt.yticks(fontsize = 30)
plt.xlabel("Club",fontsize = 35)
plt.ylabel("Total value of purchase in £ million",fontsize = 35)
plt.title("Total value of purchase based on club bought",fontsize = 50)
# Out:
# Text(0.5, 1.0, 'Total value of purchase based on club bought')

# %%
#Total money spent by Chelsea
mcdf = df[df['club_name']=='Chelsea FC']
mcf = mcdf['fee_cleaned'].sum()
print('Chelsea FC spent £{:.2f} million'.format(mcf))
# Out:
# Chelsea FC spent £274.14 million

# %%
#Total money spent on Centre-Forwards
cdf = df[df['position']=='Centre-Back']
cf = cdf['fee_cleaned'].sum()
print(' £{:.2f} million was spent on centre-backs'.format(cf))
# Out:
#  £301.25 million was spent on centre-backs

# %%
#Total money spent on Players of age 22
adf = df[df['age']==22]
af = adf['fee_cleaned'].sum()
print(' £{:.2f} million was spent on players of age 23'.format(af))
# Out:
#  £148.28 million was spent on players of age 23
