# %%
#Importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Importing the file
file = "english_premier_league.csv"

# %%
df = pd.read_csv(file)
df.head()
# Out:
#          club_name   player_name  age            position club_involved_name  \
# 0  Manchester City         Rodri   23  Defensive Midfield    Atlético Madrid
# 1  Manchester City  João Cancelo   25          Right-Back           Juventus
# 2  Manchester City   Pedro Porro   19          Right-Back             Girona
# 3  Manchester City      Angeliño   22           Left-Back      PSV Eindhoven
# 4  Manchester City  Zack Steffen   24          Goalkeeper      Columbus Crew
#
#        fee transfer_movement  fee_cleaned     league_name  year     season
# 0  £63.00m                in         63.0  Premier League  2019  2019/2020
# 1  £58.50m                in         58.5  Premier League  2019  2019/2020
# 2  £10.80m                in         10.8  Premier League  2019  2019/2020
# 3  £10.80m                in         10.8  Premier League  2019  2019/2020
# 4   £7.20m                in          7.2  Premier League  2019  2019/2020

# %%
#Basic Pandas functions
df.tail()
df.shape
df.info
# Out:
# <bound method DataFrame.info of            club_name       player_name  age            position  \
# 0    Manchester City             Rodri   23  Defensive Midfield
# 1    Manchester City      João Cancelo   25          Right-Back
# 2    Manchester City       Pedro Porro   19          Right-Back
# 3    Manchester City          Angeliño   22           Left-Back
# 4    Manchester City      Zack Steffen   24          Goalkeeper
# ..               ...               ...  ...                 ...
# 558      Aston Villa       Alan Hutton   34          Right-Back
# 559      Aston Villa    Micah Richards   31          Right-Back
# 560      Aston Villa         Mark Bunn   34          Goalkeeper
# 561      Aston Villa  Birkir Bjarnason   31    Central Midfield
# 562      Aston Villa    Anwar El Ghazi   24        Right Winger
#
#     club_involved_name                      fee transfer_movement  \
# 0      Atlético Madrid                  £63.00m                in
# ...

# %%
# %matplotlib inline
plt.rcParams['figure.figsize']=20,10
t = 563

# %%
#Based on Position
a = df['position']
av = df['position'].value_counts()
a_dict = list(dict.fromkeys(a))
plt.plot(av,c ='Black' , ls='--', marker = 's', ms=14)

# %%
#Based on Fee Cleaned
b = df['fee_cleaned']
bv = df['fee_cleaned'].value_counts()
b_dict = list(dict.fromkeys(c))
plt.plot(bv,c ='Magenta' , ls='', marker = 'o', ms=7)

# %%
#Based on Age
c = df['age']
cv = df['age'].value_counts()
c_dict = list(dict.fromkeys(c))
plt.plot(cv,c ='Red' , ls='', marker = 'o', ms=14)

# %%
#Based on the club that bought players
d = df['club_name']
dv = df['club_name'].value_counts()
d_dict = list(dict.fromkeys(d))
plt.plot(dv,c ='Blue' , ls='dashdot', marker = '^', ms=14)
