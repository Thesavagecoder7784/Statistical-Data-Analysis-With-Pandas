# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = 'NBA.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Rank                   Player Pos  \
# 0     1  Kareem Abdul-Jabbar*[6]   C
# 1     2             Karl Malone*  PF
# 2     3            LeBron James^  SF
# 3     4             Kobe Bryantβ  SG
# 4     5          Michael Jordan*  SG
#
#                           Team(s) played for (years) Total points  \
# 0  Milwaukee Bucks (1969–1975)Los Angeles Lakers ...       38,387
# 1  Utah Jazz (1985–2003)Los Angeles Lakers (2003–...       36,928
# 2  Cleveland Cavaliers (2003–2010, 2014–2018)Miam...       34,087
# 3                     Los Angeles Lakers (1996–2016)       33,643
# 4  Chicago Bulls (1984–1993, 1995–1998)Washington...       32,292
#
#   Games  played  Points  per game Field goalsmade Three-pointfield goalsmade  \
# 0         1,560              24.6          15,837                          1
# 1         1,476              25.0          13,528                         85
# 2         1,258              27.1          12,424                      1,860
# ...

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Rank                        50 non-null     int64
#  1   Player                      50 non-null     object
#  2   Pos                         50 non-null     object
#  3   Team(s) played for (years)  50 non-null     object
#  4   Total points                50 non-null     object
#  5   Games  played               50 non-null     object
#  6   Points  per game            50 non-null     float64
#  7   Field goalsmade             50 non-null     object
#  8   Three-pointfield goalsmade  43 non-null     object
#  9   Free  throws made           50 non-null     object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 4.0+ KB
# (50, 10)

# %%
# %matplotlib inline
plt.rcParams['figure.figsize']=30,15

# %% [markdown]
# PLAYER

# %%
a = df['Pos']
av = df['Pos'].value_counts()
a_dict = list(dict.fromkeys(a))
plt.plot(a,df['Player'],c ='Black' , ls='', marker = 'o', ms=14)
print(av)
plt.show()
# Out:
# C        9
# SF       8
# SG       8
# PF/C     6
# PG       4
# PF       3
# SG/SF    3
# SF/SG    2
# SG/PG    2
# PF/SF    2
# SF/PF    1
# PG/SG    1
# C/PF     1
# Name: Pos, dtype: int64

# %%
b = df['Games  played']
bv = df['Games  played'].value_counts()
b_dict = list(dict.fromkeys(b))
plt.plot(b,df['Player'],c ='Red' , ls='', marker = 's', ms=10)
plt.show()

# %%
c = df['Total points']
cv = df['Total points'].value_counts()
c_dict = list(dict.fromkeys(c))
plt.plot(c,df['Player'],c ='Blue' , ls='', marker = 's', ms=10)
plt.show()

# %%
d = df['Points  per game']
dv = df['Points  per game'].value_counts()
d_dict = list(dict.fromkeys(d))
plt.plot(d,df['Player'],c ='Blue' , ls='', marker = 's', ms=10)
plt.show()

# %%
e = df['Field goalsmade']
ev = df['Field goalsmade'].value_counts()
e_dict = list(dict.fromkeys(e))
plt.plot(e,df['Player'],c ='Blue' , ls='', marker = 's', ms=10)
plt.show()

# %%
f = df['Free  throws made']
fv = df['Free  throws made'].value_counts()
f_dict = list(dict.fromkeys(f))
plt.plot(f,df['Player'],c ='Blue' , ls='', marker = 's', ms=10)
plt.show()

# %% [markdown]
# POSITION

# %%
g = df['Games  played']
gv = df['Games  played'].value_counts()
g_dict = list(dict.fromkeys(g))
plt.plot(g,df['Pos'],c ='Red' , ls='', marker = 's', ms=10)
plt.show()

# %%
h = df['Points  per game']
hv = df['Points  per game'].value_counts()
h_dict = list(dict.fromkeys(h))
plt.plot(h,df['Pos'],c ='Blue' , ls='', marker = 's', ms=10)
plt.show()
