# %%
#In this model we are going to analyse the IPL Auction of 2020 
#First import the neccesary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Using pandas to read the file
#You would have to download the dataset
file = "IPL data.csv"
df = pd.read_csv(file)

# %%
#Show the first 5 rows
df.head()
# Out:
#    S.No Set No  Set           Name  Country Playing Role  IPL Matches  \
# 0     1      1  BA1     Chris Lynn      NaN      Batsman         41.0
# 1     2      1  BA1    Eoin Morgan      NaN      Batsman         52.0
# 2     3      1  BA1  Robin Uthappa      NaN      Batsman        177.0
# 3     4      1  BA1      Jason Roy      NaN      Batsman          8.0
# 4     5      1  BA1    Aaron Finch      NaN      Batsman         75.0
#
#   Capped / Uncapped /Associate  Reserve Price(in ₹ Lacs)  \
# 0                       Capped                       200
# 1                       Capped                       200
# 2                       Capped                       150
# 3                       Capped                       150
# 4                       Capped                       100
#
#                  IPL 2020 Team  Auctioned Price(in ₹ Lacs) IPL 2019 Team  \
# 0               Mumbai Indians                         200           KKR
# 1        Kolkata Knight Riders                         525           NaN
# 2             Rajasthan Royals                         300           KKR
# 3               Delhi Capitals                         150           NaN
# 4  Royal Challengers Bangalore                         440           NaN
#
#                       IPL Team(s)
# 0         Deccan Chargers,SRH,KKR
# 1             RCB, KKR, SRH, KXIP
# 2               MI, RCB, PWI, KKR
# 3                           GL,DD
# 4  RR, DD, PWI, SRH, MI, GL, KXIP

# %%
df['IPL Matches'] = df['IPL Matches'].fillna(0)
df['IPL 2019 Team'] = df['IPL 2019 Team'].fillna("No Team")
df.head()
# Out:
#    S.No Set No  Set           Name  Country Playing Role  IPL Matches  \
# 0     1      1  BA1     Chris Lynn      NaN      Batsman         41.0
# 1     2      1  BA1    Eoin Morgan      NaN      Batsman         52.0
# 2     3      1  BA1  Robin Uthappa      NaN      Batsman        177.0
# 3     4      1  BA1      Jason Roy      NaN      Batsman          8.0
# 4     5      1  BA1    Aaron Finch      NaN      Batsman         75.0
#
#   Capped / Uncapped /Associate  Reserve Price(in ₹ Lacs)  \
# 0                       Capped                       200
# 1                       Capped                       200
# 2                       Capped                       150
# 3                       Capped                       150
# 4                       Capped                       100
#
#                  IPL 2020 Team  Auctioned Price(in ₹ Lacs) IPL 2019 Team  \
# 0               Mumbai Indians                         200           KKR
# 1        Kolkata Knight Riders                         525       No Team
# 2             Rajasthan Royals                         300           KKR
# 3               Delhi Capitals                         150       No Team
# 4  Royal Challengers Bangalore                         440       No Team
#
#                       IPL Team(s)
# 0         Deccan Chargers,SRH,KKR
# 1             RCB, KKR, SRH, KXIP
# 2               MI, RCB, PWI, KKR
# 3                           GL,DD
# 4  RR, DD, PWI, SRH, MI, GL, KXIP

# %%
fs = df['Auctioned Price(in ₹ Lacs)'].sum()
print("₹{} Lacs were spent in the IPL Auction 2020".format(fs))
# Out:
# ₹14030 Lacs were spent in the IPL Auction 2020

# %%
#A line to display the matplotlib in the notebook itself
# %matplotlib inline
plt.rcParams['figure.figsize']=30,15

# %%
mylist = list(df['IPL 2020 Team'])
mylist = list(dict.fromkeys(mylist))
print(mylist)
# Out:
# ['Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals', 'Delhi Capitals', 'Royal Challengers Bangalore', 'Kings XI Punjab', 'Chennai Super Kings', 'Sunrisers Hyderabad']

# %%
#Calculating the difference between auctioned and reserved price
a = df['Auctioned Price(in ₹ Lacs)'] - df['Reserve Price(in ₹ Lacs)']
av = a.value_counts()
av.head()
print(a)
# Out:
# 0       0
# 1     325
# 2     150
# 3       0
# 4     340
#      ...
# 57      0
# 58      0
# 59      0
# 60      0
# 61      0
# Length: 62, dtype: int64

# %%
df['Increase from R to A'] = a
df.head()
# Out:
#    S.No Set No  Set           Name  Country Playing Role  IPL Matches  \
# 0     1      1  BA1     Chris Lynn      NaN      Batsman         41.0
# 1     2      1  BA1    Eoin Morgan      NaN      Batsman         52.0
# 2     3      1  BA1  Robin Uthappa      NaN      Batsman        177.0
# 3     4      1  BA1      Jason Roy      NaN      Batsman          8.0
# 4     5      1  BA1    Aaron Finch      NaN      Batsman         75.0
#
#   Capped / Uncapped /Associate  Reserve Price(in ₹ Lacs)  \
# 0                       Capped                       200
# 1                       Capped                       200
# 2                       Capped                       150
# 3                       Capped                       150
# 4                       Capped                       100
#
#                  IPL 2020 Team  Auctioned Price(in ₹ Lacs) IPL 2019 Team  \
# 0               Mumbai Indians                         200           KKR
# 1        Kolkata Knight Riders                         525       No Team
# 2             Rajasthan Royals                         300           KKR
# 3               Delhi Capitals                         150       No Team
# 4  Royal Challengers Bangalore                         440       No Team
#
#                       IPL Team(s)  Increase from R to A
# 0         Deccan Chargers,SRH,KKR                     0
# 1             RCB, KKR, SRH, KXIP                   325
# 2               MI, RCB, PWI, KKR                   150
# 3                           GL,DD                     0
# 4  RR, DD, PWI, SRH, MI, GL, KXIP                   340

# %%
#36 Players were sold at their base price!!!
#Pretty insightful
#Let's plot it
#To plot it
plt.plot(av,c ='Red' , ls='', marker = 'o', ms=20)
#c - colour
# ls - line style
# marker - marker type
#ms - marker size

#The x-axis marks(ticks) - (0,200,400,600)
plt.xticks(fontsize = 25)
#The y-axis marks(ticks) - (0,5,10,15,20,25)
plt.yticks(fontsize = 25)
#The label of the y-axis
plt.ylabel("Number of players ",fontsize = 25)
#The label of the x-axis
plt.xlabel("Difference between Auctioned and Reserve Price",fontsize = 25)
#The title of the plot
plt.title("Difference b/w Auctioned & Reserve Price vs number of players",fontsize = 40)
#We will follow a similiar approcah for all the other plots
# Out:
# Text(0.5, 1.0, 'Difference b/w Auctioned & Reserve Price vs number of players')

# %%
#Finding how many number of players bought based on number of IPL Matches played
sns.countplot(x = 'IPL Matches',data = df,
              palette = 'plasma_r',)
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(fontsize = 30,rotation = 65)
plt.yticks(fontsize = 30)
plt.xlabel("IPL Matches played",fontsize = 35)
plt.ylabel("Number of players",fontsize = 35)
plt.title("Number of players bought by number of IPL Matches played",fontsize = 50)
plt.show()

# %%
#Finding how many number of players each team bought
d = df['IPL 2020 Team']
dv = df['IPL 2020 Team'].value_counts()
print(dv)
dv.plot(kind = 'bar',color = ['palevioletred','red','darkmagenta','mediumblue','firebrick','darkorange','midnightblue','yellow'])
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(fontsize = 25,rotation = 45)
plt.yticks(fontsize = 25)
plt.xlabel("Team that bought players",fontsize = 30)
plt.ylabel("Number of players",fontsize = 30)
plt.title("Number of players each team bought",fontsize = 50)
plt.show()
# Out:
# Rajasthan Royals               11
# Kings XI Punjab                 9
# Kolkata Knight Riders           9
# Delhi Capitals                  8
# Royal Challengers Bangalore     8
# Sunrisers Hyderabad             7
# Mumbai Indians                  6
# Chennai Super Kings             4
# Name: IPL 2020 Team, dtype: int64

# %%
##Finding how many percent of total number of players each team bought in pie chart
plt.pie(dv,labels =mylist,
        colors = ['midnightblue','darkmagenta','pink','mediumblue',
                  'firebrick','darkred','yellow','darkorange'],
        autopct='%1.1f%%', textprops={'fontsize': 20})
plt.xticks(fontsize = 100)
plt.title("Total number of players bought based on club ",fontsize = 50)
plt.legend(loc = 'center')
plt.show()

# %%
#Finding how many number of players each team sold
e = df['IPL 2019 Team'].value_counts()
print(e)
e.plot(kind = 'bar',color = ['black','darkmagenta','firebrick','palevioletred','midnightblue','darkorange','mediumblue'])
plt.xticks(fontsize = 25,rotation = 0)
plt.yticks(fontsize = 25)
plt.xlabel("Team that sold players",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players each team sold",fontsize = 50)
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.show()
# Out:
# No Team    45
# KKR         4
# RCB         4
# KXIP        4
# RR          3
# DC          1
# SRH         1
# Name: IPL 2019 Team, dtype: int64

# %%
#Findind the correlation between number of players sold and capped/uncapped players
f = df['Capped / Uncapped /Associate'].value_counts()
print(f)
f.plot(kind = 'bar',color = ['green','red'])
plt.show
plt.xticks(fontsize =25,rotation = 0)
plt.yticks(fontsize = 25)
plt.xlabel("Capped/Uncapped",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players capped and uncapped",fontsize = 40)
# Out:
# Capped      32
# Uncapped    30
# Name: Capped / Uncapped /Associate, dtype: int64
# Text(0.5, 1.0, 'Number of players capped and uncapped')

# %%
#Finding the correlation between playing role and number of players sold
g = df['Playing Role'].value_counts()
print(g)
sns.countplot(x = 'Playing Role',data = df,
              palette = 'summer',
             order = df['Playing Role'].value_counts().index)
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(fontsize =25,rotation = 0)
plt.yticks(fontsize = 25)
plt.xlabel("Playing role",fontsize = 35)
plt.ylabel("Number of players",fontsize = 35)
plt.title("Number of players based on playing role",fontsize = 50)
# Out:
# All Rounder      26
# Batsman          12
# Fast Bowler       9
# Wicket Keeper     6
# Bowler            5
# Spinner           4
# Name: Playing Role, dtype: int64
# Text(0.5, 1.0, 'Number of players based on playing role')

# %%
a = df['Playing Role']
a = list(dict.fromkeys(a))
print(a)

labels = df['Playing Role']
plt.pie(g, labels = a ,
        autopct='%1.1f%%', textprops={'fontsize': 20})
plt.xticks(fontsize = 100)
plt.title("Total number of players bought based playing role ",fontsize = 50)
plt.legend(loc = 'center')
plt.show()
# Out:
# ['Batsman', 'All Rounder', 'Wicket Keeper', 'Fast Bowler', 'Spinner', 'Bowler']

# %%
#Finding the correlation between auctioned and number of players sold
h = df['Auctioned Price(in ₹ Lacs)'].value_counts()
h.head()
sns.countplot(x = 'Auctioned Price(in ₹ Lacs)',data = df,
              palette = 'icefire',)
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(fontsize =25)
plt.yticks(fontsize = 25)
plt.xlabel("Auctioned Price(in ₹ Lacs)",fontsize = 30)
plt.ylabel("Number of players",fontsize = 30)
plt.title("Number of players in per price",fontsize = 40)
# Out:
# Text(0.5, 1.0, 'Number of players in per price')

# %%
#Finding the correlation between reserved price and number of players sold
i = df['Reserve Price(in ₹ Lacs)'].value_counts()
print(i)
sns.countplot(x = 'Reserve Price(in ₹ Lacs)',data = df,
              palette = 'ocean',)
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(fontsize =25)
plt.yticks(fontsize = 25)
plt.xlabel("Reserve Price(in ₹ Lacs)",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players in per price",fontsize = 40)
adf = df[df['Auctioned Price(in ₹ Lacs)']>=0].groupby(df['IPL 2020 Team']).sum()
adf = tadf[['Auctioned Price(in ₹ Lacs)']]
print(adf)
# Out:
# 20     28
# 50      9
# 100     9
# 200     7
# 150     5
# 75      2
# 40      1
# 30      1
# Name: Reserve Price(in ₹ Lacs), dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-73fdde031153> in <module>
#      11 plt.title("Number of players in per price",fontsize = 40)
#      12 adf = df[df['Auctioned Price(in ₹ Lacs)']>=0].groupby(df['IPL 2020 Team']).sum()
# ---> 13 adf = tadf[['Auctioned Price(in ₹ Lacs)']]
#      14 print(adf)
#
# NameError: name 'tadf' is not defined

# %%
adf.plot(kind = 'bar')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(fontsize =25,rotation = 65)
plt.yticks(fontsize = 25)
plt.xlabel("Team",fontsize = 25,rotation = 0)
plt.ylabel("Auctioned Price(in ₹ Lacs)",fontsize = 25)
plt.title("Auctioned Price(in ₹ Lacs) per team",fontsize = 40)
print(adf['Auctioned Price(in ₹ Lacs)'])

# %%
tadf.plot(kind = 'bar')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(fontsize =25,rotation = 65)
plt.yticks(fontsize = 25)
plt.xlabel("Team",fontsize = 25,rotation = 0)
plt.ylabel("Reserve and Auctioned Price(in ₹ Lacs)",fontsize = 25)
plt.title("Reserve and Auctioned Price(in ₹ Lacs) per team",fontsize = 40)

# %%
tadf = df[df['Auctioned Price(in ₹ Lacs)']>=0].groupby(df['IPL 2020 Team']).sum()
tadf = tadf[['Reserve Price(in ₹ Lacs)','Auctioned Price(in ₹ Lacs)']]
tap = tadf['Auctioned Price(in ₹ Lacs)']
tadf
# Out:
#                              Reserve Price(in ₹ Lacs)  \
# IPL 2020 Team
# Chennai Super Kings                               420
# Delhi Capitals                                    590
# Kings XI Punjab                                   495
# Kolkata Knight Riders                             630
# Mumbai Indians                                    410
# Rajasthan Royals                                  675
# Royal Challengers Bangalore                       710
# Sunrisers Hyderabad                               350
#
#                              Auctioned Price(in ₹ Lacs)
# IPL 2020 Team
# Chennai Super Kings                                1445
# Delhi Capitals                                     1885
# Kings XI Punjab                                    2620
# Kolkata Knight Riders                              2715
# Mumbai Indians                                     1110
# Rajasthan Royals                                   1415
# Royal Challengers Bangalore                        2150
# Sunrisers Hyderabad                                 690

# %%
tadf['Auctioned Price(in ₹ Lacs)'].sum()
# Out:
# 14030

# %%
labels = df['IPL 2020 Team']
plt.pie(tap, labels = mylist,
        colors = ['midnightblue','darkmagenta','pink','mediumblue',
                  'firebrick','darkred','yellow','darkorange',],
        autopct='%1.1f%%', textprops={'fontsize': 20})
plt.xticks(fontsize = 100)
plt.title("Total value of purchase based on club bought",fontsize = 50)
plt.legend(loc = 'center')
plt.show()

# %%
tap
# Out:
# IPL 2020 Team
# Chennai Super Kings            1445
# Delhi Capitals                 1885
# Kings XI Punjab                2620
# Kolkata Knight Riders          2715
# Mumbai Indians                 1110
# Rajasthan Royals               1415
# Royal Challengers Bangalore    2150
# Sunrisers Hyderabad             690
# Name: Auctioned Price(in ₹ Lacs), dtype: int64

# %%
mylist = list(df['IPL 2020 Team'])
mylist = list(dict.fromkeys(mylist))
print(mylist)
# Out:
# ['Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals', 'Delhi Capitals', 'Royal Challengers Bangalore', 'Kings XI Punjab', 'Chennai Super Kings', 'Sunrisers Hyderabad']

# %%
padf = df[df['Auctioned Price(in ₹ Lacs)']>=0].groupby(df['Playing Role']).sum()
padf = padf[['Reserve Price(in ₹ Lacs)','Auctioned Price(in ₹ Lacs)']]
pap = padf['Auctioned Price(in ₹ Lacs)']
padf
# Out:
#                Reserve Price(in ₹ Lacs)  Auctioned Price(in ₹ Lacs)
# Playing Role
# All Rounder                        1815                        7245
# Batsman                            1135                        3055
# Bowler                              390                         390
# Fast Bowler                         630                        1990
# Spinner                             160                         915
# Wicket Keeper                       150                         435

# %%
p = list(df['Playing Role'])
p = list(dict.fromkeys(p))
p
# Out:
# ['Batsman', 'All Rounder', 'Wicket Keeper', 'Fast Bowler', 'Spinner', 'Bowler']

# %%
plt.pie(pap, labels = p ,autopct='%1.1f%%', textprops={'fontsize': 20})
plt.xticks(fontsize = 50)
plt.title("Total value of purchase based on club bought",fontsize = 50)
plt.legend(loc = 'center')
plt.show()

# %%
c = list(df['Capped / Uncapped /Associate'])
c = list(dict.fromkeys(c))
c
# Out:
# ['Capped', 'Uncapped']

# %%
pytdf = df[df['Auctioned Price(in ₹ Lacs)']>=0].groupby(df['Capped / Uncapped /Associate']).sum()
pytdf = pytdf[['Reserve Price(in ₹ Lacs)','Auctioned Price(in ₹ Lacs)']]
pyt = pytdf['Auctioned Price(in ₹ Lacs)']
plt.pie(pyt, labels = c ,autopct='%1.1f%%', textprops={'fontsize': 25})
plt.xticks(fontsize = 50)
plt.title("Total value of purchase based on capped or uncapped",fontsize = 50)
plt.legend(loc = 'center')
plt.show()

# %%
pytdf
# Out:
#                               Reserve Price(in ₹ Lacs)  \
# Capped / Uncapped /Associate
# Capped                                            3570
# Uncapped                                           710
#
#                               Auctioned Price(in ₹ Lacs)
# Capped / Uncapped /Associate
# Capped                                             11955
# Uncapped                                            2075

# %%
iplmdf = df[df['Auctioned Price(in ₹ Lacs)']>=0].groupby(df['IPL Matches']).sum()
iplmdf = iplmdf[['Reserve Price(in ₹ Lacs)','Auctioned Price(in ₹ Lacs)']]
iplmdf
# Out:
#              Reserve Price(in ₹ Lacs)  Auctioned Price(in ₹ Lacs)
# IPL Matches
# 0.0                              1080                        2980
# 1.0                                50                         455
# 3.0                                20                          20
# 4.0                               100                         100
# 5.0                               150                         875
# 8.0                               150                         150
# 11.0                               75                         300
# 14.0                              150                         400
# 16.0                              300                        2100
# 18.0                              150                         150
# 20.0                              200                         200
# 26.0                              100                         800
# 29.0                              100                         480
# 33.0                               20                          20
# 34.0                               20                          60
# 41.0                              200                         200
# 52.0                              200                         525
# 61.0                              190                        1050
# 69.0                              200                        1075
# 73.0                              100                         300
# 75.0                              100                         440
# 79.0                               75                          75
# 81.0                               50                          50
# 85.0                               50                          50
# 92.0                              200                         200
# 157.0                             100                         675
# 177.0                             150                         300

# %%
iplmdf.plot()

# %%
padf['Playing Role'] = df['Playing Role']
del padf['Playing Role']
padf
# Out:
#                Reserve Price(in ₹ Lacs)  Auctioned Price(in ₹ Lacs)
# Playing Role
# All Rounder                        1815                        7245
# Batsman                            1135                        3055
# Bowler                              390                         390
# Fast Bowler                         630                        1990
# Spinner                             160                         915
# Wicket Keeper                       150                         435

# %%
    pap
# Out:
# Playing Role
# All Rounder      7245
# Batsman          3055
# Bowler            390
# Fast Bowler      1990
# Spinner           915
# Wicket Keeper     435
# Name: Auctioned Price(in ₹ Lacs), dtype: int64

# %%
tadf['Auctioned Price(in ₹ Lacs)'].plot(kind = 'bar',color = ['yellow','mediumblue','red','darkmagenta','midnightblue',
                              'palevioletred','firebrick','darkorange'])
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(fontsize = 30,rotation = 60)
plt.yticks(fontsize = 30)
plt.xlabel("IPL Team ",fontsize = 40)
plt.ylabel("Amount of ₹ lakhs spent ",fontsize = 40)
plt.title("Amount of ₹ lakhs spent by each team ",fontsize = 60)
plt.show()

# %%
df['IPL 2020 Team'].value_counts()
# Out:
# Rajasthan Royals               11
# Kings XI Punjab                 9
# Kolkata Knight Riders           9
# Delhi Capitals                  8
# Royal Challengers Bangalore     8
# Sunrisers Hyderabad             7
# Mumbai Indians                  6
# Chennai Super Kings             4
# Name: IPL 2020 Team, dtype: int64

# %%
tap
# Out:
# IPL 2020 Team
# Chennai Super Kings            1445
# Delhi Capitals                 1885
# Kings XI Punjab                2620
# Kolkata Knight Riders          2715
# Mumbai Indians                 1110
# Rajasthan Royals               1415
# Royal Challengers Bangalore    2150
# Sunrisers Hyderabad             690
# Name: Auctioned Price(in ₹ Lacs), dtype: int64

# %%
tadf
# Out:
#                              Reserve Price(in ₹ Lacs)  \
# IPL 2020 Team
# Chennai Super Kings                               420
# Delhi Capitals                                    590
# Kings XI Punjab                                   495
# Kolkata Knight Riders                             630
# Mumbai Indians                                    410
# Rajasthan Royals                                  675
# Royal Challengers Bangalore                       710
# Sunrisers Hyderabad                               350
#
#                              Auctioned Price(in ₹ Lacs)
# IPL 2020 Team
# Chennai Super Kings                                1445
# Delhi Capitals                                     1885
# Kings XI Punjab                                    2620
# Kolkata Knight Riders                              2715
# Mumbai Indians                                     1110
# Rajasthan Royals                                   1415
# Royal Challengers Bangalore                        2150
# Sunrisers Hyderabad                                 690

# %%
del tadf['Reserve Price(in ₹ Lacs)']

# %%
tadf['No. of Players'] = dv

# %%
tadf
# Out:
#                              Auctioned Price(in ₹ Lacs)  No. of Players
# IPL 2020 Team
# Chennai Super Kings                                1445               4
# Delhi Capitals                                     1885               8
# Kings XI Punjab                                    2620               9
# Kolkata Knight Riders                              2715               9
# Mumbai Indians                                     1110               6
# Rajasthan Royals                                   1415              11
# Royal Challengers Bangalore                        2150               8
# Sunrisers Hyderabad                                 690               7

# %%
tadf.to_csv('IPL Teams purchases')

# %%
ardf = df[df['Playing Role']=='All Rounder']

# %%
ardf
# Out:
#     S.No Set No    Set                    Name  Country Playing Role  \
# 5      6      2    AL1           Glenn Maxwell      NaN  All Rounder
# 6      7      2    AL1            Chris Woakes      NaN  All Rounder
# 7      8      2    AL1             Pat Cummins      NaN  All Rounder
# 8      9      2    AL1              Sam Curran      NaN  All Rounder
# 9     10      2    AL1            Chris Morris      NaN  All Rounder
# 12    13      4    FA1     Nathan Coulter-Nile      NaN  All Rounder
# 18    19      7   UAL1            Deepak Hooda      NaN  All Rounder
# 19    20      7   UAL1      Varun Chakravarthy      NaN  All Rounder
# 20    21      7   UAL1        Yashasvi Jaiswal      NaN  All Rounder
# 30    31     12    AL2          Mitchell Marsh      NaN  All Rounder
# 31    32     12    AL2           James Neesham      NaN  All Rounder
# 33    34     15   UAL2        Bavanaka Sandeep      NaN  All Rounder
# 34    35     15   UAL2             Chris Green      NaN  All Rounder
# 38    39     20    AL3            Fabian Allen      NaN  All Rounder
# 39    40     20    AL3            Chris Jordan      NaN  All Rounder
# 43    44     33   UAL4  Tajinder Singh Dhillon      NaN  All Rounder
# 44    45     33   UAL4             Abdul Samad      NaN  All Rounder
# 45    46     42   UAL6         Aniruddha Joshi      NaN  All Rounder
# 46    47     43    AL7       Digvijay Deshmukh      NaN  All Rounder
# 47    48     43    AL7      Prince Balwant Rai      NaN  All Rounder
# 48    49  [ADD]  [ADD]            Sanjay Yadav      NaN  All Rounder
# 50    51  [REC]  [REC]         Pavan Deshpande      NaN  All Rounder
# 54    55  [REC]  [REC]          Marcus Stoinis      NaN  All Rounder
# 57    58  [REC]  [REC]             Lalit Yadav      NaN  All Rounder
# 60    61  [REC]  [REC]              Tom Curran      NaN  All Rounder
# 61    62  [REC]  [REC]             Isuru Udana      NaN  All Rounder
#
#     IPL Matches Capped / Uncapped /Associate  Reserve Price(in ₹ Lacs)  \
# 5          69.0                       Capped                       200
# 6          18.0                       Capped                       150
# 7          16.0                       Capped                       200
# 8          16.0                       Capped                       100
# 9          61.0                       Capped                       150
# 12         26.0                       Capped                       100
# 18         61.0                     Uncapped                        40
# 19          1.0                     Uncapped                        30
# 20          0.0                     Uncapped                        20
# 30         20.0                       Capped                       200
# 31          4.0                       Capped                        50
# 33          0.0                     Uncapped                        20
# 34          0.0                     Uncapped                        20
# 38          0.0                       Capped                        50
# 39         11.0                       Capped                        75
# 43          0.0                     Uncapped                        20
# 44          0.0                     Uncapped                        20
# 45          0.0                     Uncapped                        20
# 46          0.0                     Uncapped                        20
# 47          0.0                     Uncapped                        20
# 48          0.0                     Uncapped                        20
# 50          0.0                     Uncapped                        20
# 54         29.0                       Capped                       100
# 57          0.0                     Uncapped                        20
# 60          5.0                       Capped                       100
# 61          0.0                       Capped                        50
#
#                   IPL 2020 Team  Auctioned Price(in ₹ Lacs) IPL 2019 Team  \
# 5               Kings XI Punjab                        1075       No Team
# 6                Delhi Capitals                         150       No Team
# 7         Kolkata Knight Riders                        1550       No Team
# 8           Chennai Super Kings                         550          KXIP
# 9   Royal Challengers Bangalore                        1000            DC
# 12               Mumbai Indians                         800           RCB
# 18              Kings XI Punjab                          50           SRH
# 19        Kolkata Knight Riders                         400          KXIP
# 20             Rajasthan Royals                         240       No Team
# 30          Sunrisers Hyderabad                         200       No Team
# 31              Kings XI Punjab                          50       No Team
# 33          Sunrisers Hyderabad                          20       No Team
# 34        Kolkata Knight Riders                          20       No Team
# 38          Sunrisers Hyderabad                          50       No Team
# 39              Kings XI Punjab                         300       No Team
# 43              Kings XI Punjab                          20       No Team
# 44          Sunrisers Hyderabad                          20       No Team
# 45             Rajasthan Royals                          20       No Team
# 46               Mumbai Indians                          20       No Team
# 47               Mumbai Indians                          20       No Team
# 48          Sunrisers Hyderabad                          20       No Team
# 50  Royal Challengers Bangalore                          20       No Team
# 54               Delhi Capitals                         480           RCB
# 57               Delhi Capitals                          20       No Team
# 60             Rajasthan Royals                         100       No Team
# 61  Royal Challengers Bangalore                          50       No Team
#
#          IPL Team(s)  Increase from R to A
# 5         MI,KXIP,DD                   875
# 6            KKR,RCB                     0
# 7          MI,KKR,DD                  1350
# 8               KXIP                   450
# 9          CSK,RR,DC                   850
# 12  MI, DD, KKR, RCB                   700
# 18            RR,SRH                    10
# 19              KXIP                   370
# 20               NaN                   220
# 30       DCH,PWI,RPS                     0
# 31                DD                     0
# 33               NaN                     0
# 34               NaN                     0
# 38               NaN                     0
# 39          RCB, SRH                   225
# 43                MI                     0
# 44               NaN                     0
# 45               RCB                     0
# 46               NaN                     0
# 47               NaN                     0
# 48               KKR                     0
# 50               NaN                     0
# 54          RCB,KXIP                   380
# 57               NaN                     0
# 60               KKR                     0
# 61               NaN                     0

# %%
ardf['Auctioned Price(in ₹ Lacs)'].value_counts()
# Out:
# 20      10
# 50       4
# 480      1
# 150      1
# 1075     1
# 400      1
# 240      1
# 1550     1
# 300      1
# 1000     1
# 550      1
# 100      1
# 200      1
# 800      1
# Name: Auctioned Price(in ₹ Lacs), dtype: int64

# %%
ardf['IPL 2020 Team'].value_counts()
# Out:
# Sunrisers Hyderabad            5
# Kings XI Punjab                5
# Delhi Capitals                 3
# Royal Challengers Bangalore    3
# Mumbai Indians                 3
# Kolkata Knight Riders          3
# Rajasthan Royals               3
# Chennai Super Kings            1
# Name: IPL 2020 Team, dtype: int64

# %%
ardf['IPL Matches'].value_counts()
# Out:
# 0.0     13
# 61.0     2
# 16.0     2
# 5.0      1
# 29.0     1
# 11.0     1
# 4.0      1
# 20.0     1
# 1.0      1
# 26.0     1
# 18.0     1
# 69.0     1
# Name: IPL Matches, dtype: int64

# %%
ardf['Auctioned Price(in ₹ Lacs)'].max()
# Out:
# 1550

# %%
ardf['Auctioned Price(in ₹ Lacs)'].min()
# Out:
# 20

# %%
aradf = df[df['Auctioned Price(in ₹ Lacs)']>=0].groupby(df['Playing Role']).sum()

# %%
aradf['Number of players'] = g

# %%
aradf
# Out:
#                S.No  Country  IPL Matches  Reserve Price(in ₹ Lacs)  \
# Playing Role
# All Rounder     890      0.0        337.0                      1815
# Batsman         191      0.0        552.0                      1135
# Bowler          270      0.0        177.0                       390
# Fast Bowler     251      0.0         91.0                       630
# Spinner         111      0.0        190.0                       160
# Wicket Keeper   240      0.0          4.0                       150
#
#                Auctioned Price(in ₹ Lacs)  Increase from R to A  \
# Playing Role
# All Rounder                          7245                  5430
# Batsman                              3055                  1920
# Bowler                                390                     0
# Fast Bowler                          1990                  1360
# Spinner                               915                   755
# Wicket Keeper                         435                   285
#
#                Number of players
# Playing Role
# All Rounder                   26
# Batsman                       12
# Bowler                         5
# Fast Bowler                    9
# Spinner                        4
# Wicket Keeper                  6

# %%
aradf['Auctioned Price(in ₹ Lacs)'].plot(kind = 'bar',color = ['midnightblue','navy','darkblue',
                                                              'mediumblue','blue','royalblue'])
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(fontsize =30,rotation = 55)
plt.yticks(fontsize = 30)
plt.xlabel("Position",fontsize = 35,rotation = 0)
plt.ylabel("Auctioned Price(in ₹ Lacs)",fontsize = 35)
plt.title("Auctioned Price(in ₹ Lacs) per position",fontsize = 50)
print(aradf['Auctioned Price(in ₹ Lacs)'])
plt.savefig("Auctioned Price(in ₹ Lacs) per position.pdf")
# Out:
# Playing Role
# All Rounder      7245
# Batsman          3055
# Bowler            390
# Fast Bowler      1990
# Spinner           915
# Wicket Keeper     435
# Name: Auctioned Price(in ₹ Lacs), dtype: int64

# %%
aradf['Number of players'].plot()

# %%
bdf = df[df['Playing Role']=='Wicket Keeper']
bdf
# Out:
#     S.No Set No    Set               Name  Country   Playing Role  \
# 10    11      3    WK1         Alex Carey      NaN  Wicket Keeper
# 21    22      8   UWK1         Anuj Rawat      NaN  Wicket Keeper
# 35    36     16   UWK2      Josh Philippe      NaN  Wicket Keeper
# 51    52  [REC]  [REC]  Prab Simran Singh      NaN  Wicket Keeper
# 58    59  [REC]  [REC]      Shahbaz Ahmed      NaN  Wicket Keeper
# 59    60  [REC]  [REC]        Nikhil Naik      NaN  Wicket Keeper
#
#     IPL Matches Capped / Uncapped /Associate  Reserve Price(in ₹ Lacs)  \
# 10          0.0                       Capped                        50
# 21          0.0                     Uncapped                        20
# 35          0.0                     Uncapped                        20
# 51          1.0                     Uncapped                        20
# 58          0.0                     Uncapped                        20
# 59          3.0                     Uncapped                        20
#
#                   IPL 2020 Team  Auctioned Price(in ₹ Lacs) IPL 2019 Team  \
# 10               Delhi Capitals                         240       No Team
# 21             Rajasthan Royals                          80       No Team
# 35  Royal Challengers Bangalore                          20       No Team
# 51              Kings XI Punjab                          55          KXIP
# 58  Royal Challengers Bangalore                          20       No Team
# 59        Kolkata Knight Riders                          20           KKR
#
#    IPL Team(s)  Increase from R to A
# 10         NaN                   190
# 21         NaN                    60
# 35         NaN                     0
# 51        KXIP                    35
# 58         NaN                     0
# 59    KKR,KXIP                     0

# %%
bdf['Auctioned Price(in ₹ Lacs)'].max()
# Out:
# 240

# %%
bdf['IPL 2020 Team'].value_counts()
# Out:
# Royal Challengers Bangalore    2
# Delhi Capitals                 1
# Kolkata Knight Riders          1
# Rajasthan Royals               1
# Kings XI Punjab                1
# Name: IPL 2020 Team, dtype: int64

# %%
bwdf = df[df['Playing Role']=='Bowler']
bwdf['IPL 2020 Team'].value_counts()
# Out:
# Delhi Capitals                 2
# Rajasthan Royals               1
# Chennai Super Kings            1
# Royal Challengers Bangalore    1
# Name: IPL 2020 Team, dtype: int64

# %%
bwdf = df[df['Playing Role']=='Spinner']
bwdf
# Out:
#     S.No Set No   Set           Name  Country Playing Role  IPL Matches  \
# 14    15      5   SP1  Piyush Chawla      NaN      Spinner        157.0
# 25    26     10  USP1    M Siddharth      NaN      Spinner          0.0
# 26    27     10  USP1   Ravi Bishnoi      NaN      Spinner          0.0
# 42    43     28  USP3   Pravin Tambe      NaN      Spinner         33.0
#
#    Capped / Uncapped /Associate  Reserve Price(in ₹ Lacs)  \
# 14                       Capped                       100
# 25                     Uncapped                        20
# 26                     Uncapped                        20
# 42                       Capped                        20
#
#             IPL 2020 Team  Auctioned Price(in ₹ Lacs) IPL 2019 Team  \
# 14    Chennai Super Kings                         675           KKR
# 25  Kolkata Knight Riders                          20       No Team
# 26        Kings XI Punjab                         200       No Team
# 42  Kolkata Knight Riders                          20       No Team
#
#    IPL Team(s)  Increase from R to A
# 14    KXIP,KKR                   575
# 25         NaN                     0
# 26         NaN                   180
# 42   RR,GL,SRH                     0

# %%
afdf = df[df['Auctioned Price(in ₹ Lacs)']>=500].reset_index()

# %%
afdf
# Out:
#     index  S.No Set No    Set                 Name  Country Playing Role  \
# 0       1     2      1    BA1          Eoin Morgan      NaN      Batsman
# 1       4     5      1    BA1          Aaron Finch      NaN      Batsman
# 2       5     6      2    AL1        Glenn Maxwell      NaN  All Rounder
# 3       7     8      2    AL1          Pat Cummins      NaN  All Rounder
# 4       8     9      2    AL1           Sam Curran      NaN  All Rounder
# 5       9    10      2    AL1         Chris Morris      NaN  All Rounder
# 6      12    13      4    FA1  Nathan Coulter-Nile      NaN  All Rounder
# 7      13    14      4    FA1     Sheldon Cottrell      NaN  Fast Bowler
# 8      14    15      5    SP1        Piyush Chawla      NaN      Spinner
# 9      19    20      7   UAL1   Varun Chakravarthy      NaN  All Rounder
# 10     27    28     11    BA2      Shimron Hetmyer      NaN      Batsman
# 11     40    41     22    FA3      Kane Richardson      NaN  Fast Bowler
# 12     54    55  [REC]  [REC]       Marcus Stoinis      NaN  All Rounder
#
#     IPL Matches Capped / Uncapped /Associate  Reserve Price(in ₹ Lacs)  \
# 0          52.0                       Capped                       200
# 1          75.0                       Capped                       100
# 2          69.0                       Capped                       200
# 3          16.0                       Capped                       200
# 4          16.0                       Capped                       100
# 5          61.0                       Capped                       150
# 6          26.0                       Capped                       100
# 7           0.0                       Capped                        50
# 8         157.0                       Capped                       100
# 9           1.0                     Uncapped                        30
# 10          5.0                       Capped                        50
# 11         14.0                       Capped                       150
# 12         29.0                       Capped                       100
#
#                   IPL 2020 Team  Auctioned Price(in ₹ Lacs) IPL 2019 Team  \
# 0         Kolkata Knight Riders                         525       No Team
# 1   Royal Challengers Bangalore                         440       No Team
# 2               Kings XI Punjab                        1075       No Team
# 3         Kolkata Knight Riders                        1550       No Team
# 4           Chennai Super Kings                         550          KXIP
# 5   Royal Challengers Bangalore                        1000            DC
# 6                Mumbai Indians                         800           RCB
# 7               Kings XI Punjab                         850       No Team
# 8           Chennai Super Kings                         675           KKR
# 9         Kolkata Knight Riders                         400          KXIP
# 10               Delhi Capitals                         775           RCB
# 11  Royal Challengers Bangalore                         400       No Team
# 12               Delhi Capitals                         480           RCB
#
#                        IPL Team(s)  Increase from R to A
# 0              RCB, KKR, SRH, KXIP                   325
# 1   RR, DD, PWI, SRH, MI, GL, KXIP                   340
# 2                       MI,KXIP,DD                   875
# 3                        MI,KKR,DD                  1350
# 4                             KXIP                   450
# 5                        CSK,RR,DC                   850
# 6                 MI, DD, KKR, RCB                   700
# 7                              NaN                   800
# 8                         KXIP,KKR                   575
# 9                             KXIP                   370
# 10                             RCB                   725
# 11                    PWI, RR, RCB                   250
# 12                        RCB,KXIP                   380

# %%
afdf.loc[afdf['Playing Role'] == 'Batsman']
# Out:
#     index  S.No Set No  Set             Name  Country Playing Role  \
# 0       1     2      1  BA1      Eoin Morgan      NaN      Batsman
# 1       4     5      1  BA1      Aaron Finch      NaN      Batsman
# 10     27    28     11  BA2  Shimron Hetmyer      NaN      Batsman
#
#     IPL Matches Capped / Uncapped /Associate  Reserve Price(in ₹ Lacs)  \
# 0          52.0                       Capped                       200
# 1          75.0                       Capped                       100
# 10          5.0                       Capped                        50
#
#                   IPL 2020 Team  Auctioned Price(in ₹ Lacs) IPL 2019 Team  \
# 0         Kolkata Knight Riders                         525       No Team
# 1   Royal Challengers Bangalore                         440       No Team
# 10               Delhi Capitals                         775           RCB
#
#                        IPL Team(s)  Increase from R to A
# 0              RCB, KKR, SRH, KXIP                   325
# 1   RR, DD, PWI, SRH, MI, GL, KXIP                   340
# 10                             RCB                   725

# %%
afdf.loc[afdf['Playing Role'] == 'Fast Bowler']
# Out:
#     index  S.No Set No  Set              Name  Country Playing Role  \
# 7      13    14      4  FA1  Sheldon Cottrell      NaN  Fast Bowler
# 11     40    41     22  FA3   Kane Richardson      NaN  Fast Bowler
#
#     IPL Matches Capped / Uncapped /Associate  Reserve Price(in ₹ Lacs)  \
# 7           0.0                       Capped                        50
# 11         14.0                       Capped                       150
#
#                   IPL 2020 Team  Auctioned Price(in ₹ Lacs) IPL 2019 Team  \
# 7               Kings XI Punjab                         850       No Team
# 11  Royal Challengers Bangalore                         400       No Team
#
#      IPL Team(s)  Increase from R to A
# 7            NaN                   800
# 11  PWI, RR, RCB                   250

# %%
ars = aradf['Auctioned Price(in ₹ Lacs)']

# %%
ars
# Out:
# Playing Role
# All Rounder      7245
# Batsman          3055
# Bowler            390
# Fast Bowler      1990
# Spinner           915
# Wicket Keeper     435
# Name: Auctioned Price(in ₹ Lacs), dtype: int64

# %%
plt.pie(ars,labels = labels,autopct='%1.1f%%',
        shadow=True, startangle=60,
        textprops={'fontsize': 20})
labels = dict(ars)
plt.xticks(fontsize = 50)
plt.title("Total value of purchase based on club bought",fontsize = 50)
plt.legend(labels,loc = 'center')
plt.show()
