# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = 'Actor data.csv'

# %%
df = pd.read_csv(file)

# %%
df.head(26)
# Out:
#                     Actor                                               Film  \
# 0            Keanu Reeves          The Matrix ReloadedThe Matrix Revolutions
# 1            Bruce Willis                                    The Sixth Sense
# 2              Tom Cruise                              Mission: Impossible 2
# 3              Tom Cruise                                  War of the Worlds
# 4              Will Smith                                     Men in Black 3
# 5       Robert Downey Jr.                             Avengers: Infinity War
# 6       Robert Downey Jr.                                  Avengers: Endgame
# 7       Robert Downey Jr.                                         Iron Man 3
# 8          Sandra Bullock                                            Gravity
# 9               Tom Hanks                                       Forrest Gump
# 10             Tom Cruise                                Mission: Impossible
# 11          Harrison Ford  Indiana Jones and the Kingdom of the Crystal S...
# 12         Jack Nicholson                                             Batman
# 13      Leonardo DiCaprio                                          Inception
# 14            Johnny Depp        Pirates of the Caribbean: On Stranger Tides
# 15      Robert Downey Jr.                                       The Avengers
# 16           Cameron Diaz                                        Bad Teacher
# 17      Robert Downey Jr.                         Captain America: Civil War
# 18      Robert Downey Jr.                            Avengers: Age of Ultron
# 19      Leonardo DiCaprio                                            Titanic
# 20              Tom Hanks                                Saving Private Ryan
# 21            Johnny Depp                                Alice in Wonderland
# 22             Aamir Khan                                             Dangal
# 23             Jim Carrey                                            Yes Man
# 24  Arnold Schwarzenegger                 Terminator 3: Rise of the Machines
# 25             Mel Gibson                                    Lethal Weapon 4
#
#     Year       Salary  Total income             Ref
# 0   2003  $30,000,000  $156,000,000             [1]
# 1   1999  $14,000,000  $100,000,000             [1]
# 2   2000          NaN  $100,000,000             [1]
# 3   2005          NaN  $100,000,000             [1]
# 4   2012          NaN  $100,000,000             [2]
# 5   2018          NaN  $75,000,000+             [3]
# 6   2019  $20,000,000   $75,000,000             [4]
# 7   2013          NaN   $75,000,000             [5]
# 8   2013  $20,000,000  $70,000,000+             [6]
# 9   1994          NaN   $70,000,000             [1]
# 10  1996          NaN   $70,000,000             [1]
# 11  2008          NaN   $65,000,000             [7]
# 12  1989   $6,000,000   $60,000,000          [1][8]
# 13  2010          NaN   $59,000,000             [9]
# 14  2011  $35,000,000   $55,000,000         [9][10]
# 15  2012          NaN   $50,000,000            [11]
# 16  2011          NaN   $42,000,000            [12]
# 17  2016  $40,000,000  $40,000,000+             [5]
# 18  2015          NaN   $40,000,000            [13]
# 19  1997          NaN   $40,000,000             [1]
# 20  1998          NaN   $40,000,000             [1]
# 21  2010          NaN   $40,000,000             [9]
# 22  2016          NaN   $39,000,000  [nb 1][15][16]
# 23  2008          NaN   $35,000,000            [17]
# 24  2003  $29,250,000  $30,000,000+       [nb 2][1]
# 25  1998  $30,000,000   $30,000,000             [1]

# %%
a = df['Actor'].value_counts()
print(a)
# Out:
# Robert Downey Jr.        6
# Tom Cruise               3
# Johnny Depp              2
# Leonardo DiCaprio        2
# Tom Hanks                2
# Aamir Khan               1
# Jack Nicholson           1
# Keanu Reeves             1
# Arnold Schwarzenegger    1
# Cameron Diaz             1
# Jim Carrey               1
# Harrison Ford            1
# Mel Gibson               1
# Brad Pitt                1
# Bruce Willis             1
# Sandra Bullock           1
# Will Smith               1
# Name: Actor, dtype: int64

# %%
# %matplotlib inline
plt.rcParams['figure.figsize']=30,20

# %%
plt.plot(a, c ='Green' , ls='', marker = 'o', ms=30)
plt.xticks(fontsize = 25,rotation = 65)
plt.yticks(fontsize = 20)
plt.xlabel("Actor name",fontsize = 30)
plt.ylabel("Number of movies",fontsize = 30)
plt.title("Highest-earning actors for a single production",fontsize = 50)
# Out:
# Text(0.5, 1.0, 'Highest-earning actors for a single production')

# %%
b = df['Year'].value_counts()
print(b)
plt.plot(b, c ='Black' , ls='', marker = 'o', ms=30)
plt.show
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
plt.xlabel("Year",fontsize = 35)
plt.ylabel("Number of movies",fontsize = 35)
plt.title("Year and number of best selling movies",fontsize = 50)
# Out:
# 2016    2
# 2012    2
# 2011    2
# 2010    2
# 2008    2
# 2003    2
# 2013    2
# 1998    2
# 1996    1
# 2018    1
# 2019    1
# 1989    1
# 1994    1
# 2015    1
# 1997    1
# 1999    1
# 2001    1
# 2005    1
# 2000    1
# Name: Year, dtype: int64
# Text(0.5, 1.0, 'Year and number of best selling movies')

# %%
c = df['Total income'].value_counts()
print(c)
plt.plot(c, c ='Red' , ls='', marker = 'o', ms=30)
plt.xticks(fontsize = 20,rotation = 70)
plt.yticks(fontsize = 20)
plt.xlabel("Total Income",fontsize = 25)
plt.ylabel("Number of movies",fontsize = 25)
plt.title("Total income and number of best selling movies",fontsize = 50)
# Out:
# $100,000,000    4
# $40,000,000     4
# $70,000,000     2
# $30,000,000     2
# $75,000,000     2
# $70,000,000+    1
# $75,000,000+    1
# $50,000,000     1
# $42,000,000     1
# $40,000,000+    1
# $39,000,000     1
# $59,000,000     1
# $35,000,000     1
# $60,000,000     1
# $65,000,000     1
# $156,000,000    1
# $55,000,000     1
# $30,000,000+    1
# Name: Total income, dtype: int64
# Text(0.5, 1.0, 'Total income and number of best selling movies')

# %%
d = df['Salary'].value_counts()
print(d)
plt.plot(d, c ='Blue' , ls='', marker = 'o', ms=30)
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel("Salary ",fontsize = 30)
plt.ylabel("Number of actors",fontsize = 30)
plt.title("Salary and the number of actors",fontsize = 50)
# Out:
# $20,000,000    2
# $30,000,000    2
# $29,250,000    1
# $35,000,000    1
# $6,000,000     1
# $40,000,000    1
# $10,000,000    1
# $14,000,000    1
# Name: Salary, dtype: int64
# Text(0.5, 1.0, 'Salary and the number of actors')
