# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = 'madden21_ratings.csv'
df= pd.read_csv(file)
df.head()
# Out:
#        Team            Full Name  Overall Rating Position  Age  Speed  \
# 0      Rams         Aaron Donald              99       RE   29     82
# 1  Patriots      Stephon Gilmore              99       CB   29     92
# 2  Panthers  Christian McCaffrey              99       HB   24     92
# 3    Chiefs      Patrick Mahomes              99       QB   24     81
# 4    Saints       Michael Thomas              99       WR   27     89
#
#    Acceleration  Awareness  Agility  Strength  ...  Jersey Number  \
# 0            90         99       86        99  ...             99
# 1            94         99       94        70  ...             24
# 2            93         97       97        72  ...             22
# 3            87         97       88        69  ...             15
# 4            92         99       92        77  ...             13
#
#        Total Salary     Signing Bonus          Archetype  \
# 0   $101,892,000.00    $40,000,000.00     DE_PowerRusher
# ...

# %%
# %matplotlib inline
plt.rcParams['figure.figsize']=30,15

# %%
a = df['Position']
av = df['Position'].value_counts()
a_dict = list(dict.fromkeys(a))
plt.plot(av,c ='Black' , ls='', marker = 'o', ms=20)
plt.show
plt.xticks(fontsize = 25,rotation = 65)
plt.yticks(fontsize = 25)
plt.xlabel("Position",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players sold based on position",fontsize = 40)
print(av)
# Out:
# WR      280
# CB      248
# TE      181
# HB      148
# DT      133
# MLB     131
# QB      111
# RE      102
# LE       98
# SS       96
# ROLB     88
# FS       85
# RT       85
# C        84
# LOLB     81
# LG       81
# RG       81
# LT       81
# K        38
# P        35
# FB       26
# Name: Position, dtype: int64

# %%
b = df['Overall Rating']
bv = df['Overall Rating'].value_counts()
b_dict = list(dict.fromkeys(b))
plt.plot(bv,c ='Black' , ls='', marker = 'o', ms=15)
plt.show
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel("Overall Rating",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players based on overall rating",fontsize = 40)
print(bv)
# Out:
# 65    121
# 64    111
# 67    108
# 63    102
# 69    101
#      ...
# 38      1
# 33      1
# 37      1
# 43      1
# 23      1
# Name: Overall Rating, Length: 69, dtype: int64

# %%
c = df['Age']
cv = df['Age'].value_counts()
c_dict = list(dict.fromkeys(c))
plt.plot(cv,c ='Red' , ls='', marker = 'o', ms=20)
print(cv)
plt.show
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel("Age",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players based on age",fontsize = 40)
# Out:
# 24    369
# 23    334
# 25    327
# 26    275
# 27    209
# 22    172
# 28    154
# 29    122
# 30     92
# 31     63
# 21     60
# 32     45
# 33     20
# 34     15
# 35     11
# 38      7
# 37      6
# 36      6
# 39      3
# 43      1
# 41      1
# 20      1
# Name: Age, dtype: int64
# Text(0.5, 1.0, 'Number of players based on age')

# %%
d = df['Team']
dv = df['Team'].value_counts()
d_dict = list(dict.fromkeys(d))
plt.plot(dv,c ='Red' , ls='', marker = 'o', ms=20)
print(dv)
plt.show
plt.xticks(fontsize = 25,rotation = 65)
plt.yticks(fontsize = 25)
plt.xlabel("Team",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players based on team",fontsize = 40)
# Out:
# Redskins      74
# Eagles        74
# Dolphins      74
# Lions         74
# Bears         74
# Bills         74
# Jets          74
# Broncos       74
# Raiders       74
# Saints        73
# 49ers         73
# Colts         72
# Rams          71
# Patriots      71
# Giants        71
# Falcons       71
# Chargers      71
# Texans        71
# Jaguars       71
# Seahawks      71
# Cowboys       71
# Packers       70
# Chiefs        70
# Cardinals     70
# Steelers      70
# Ravens        70
# Panthers      70
# Browns        70
# Buccaneers    70
# Bengals       70
# Titans        70
# Vikings       70
# Name: Team, dtype: int64
# Text(0.5, 1.0, 'Number of players based on team')

# %%
e = df['Years Pro']
ev = df['Years Pro'].value_counts()
e_dict = list(dict.fromkeys(e))
plt.plot(ev,c ='Red' , ls='', marker = 'o', ms=20)
print(ev)
plt.show
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel("Years Pro",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players based on years pro",fontsize = 40)
# Out:
# 2     407
# 1     364
# 3     320
# 0     314
# 4     268
# 5     175
# 6     130
# 7     103
# 8      67
# 9      57
# 10     33
# 11     16
# 12     11
# 16      8
# 15      7
# 13      6
# 14      4
# 19      1
# 17      1
# 20      1
# Name: Years Pro, dtype: int64
# Text(0.5, 1.0, 'Number of players based on years pro')

# %%
f = df['College']
fv = df['College'].value_counts()
f_dict = list(dict.fromkeys(f))
print(fv)
# Out:
# Alabama                      70
# Ohio State                   57
# LSU                          53
# Florida                      49
# Miami                        44
#                              ..
# Greenville College            1
# Bowie State                   1
# Rhode Island                  1
# Kennesaw State University     1
# Grand Valley St.              1
# Name: College, Length: 272, dtype: int64

# %%
g = df['Jersey Number']
gv = g.value_counts()
print(gv)
plt.plot(gv,c ='Black' , ls='', marker = 'o', ms=15)
plt.show
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel("Jersey number",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players based on jersey number",fontsize = 40)
# Out:
# 23    33
# 26    32
# 94    31
# 11    31
# 25    30
#       ..
# 3     17
# 63    15
# 40    14
# 8     13
# 1      8
# Name: Jersey Number, Length: 99, dtype: int64
# Text(0.5, 1.0, 'Number of players based on jersey number')

# %%
h = df['Height']
hv = h.value_counts()
plt.plot(hv,c ='Black' , ls='', marker = 'o', ms=15)
plt.show
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel("Height",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players based on height",fontsize = 40)
# Out:
# Text(0.5, 1.0, 'Number of players based on height')

# %%
i = df['Weight']
iv = i.value_counts()
plt.plot(iv,c ='Black' , ls='', marker = 'o', ms=15)
plt.show
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel("Weight",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players based on weight",fontsize = 40)
print(iv)
# Out:
# 205    60
# 210    56
# 190    54
# 215    52
# 195    49
#        ..
# 279     1
# 337     1
# 339     1
# 341     1
# 160     1
# Name: Weight, Length: 184, dtype: int64

# %%
j = df['Running Style'].value_counts()
plt.plot(j,c ='Black' , ls='', marker = 'o', ms=15)
plt.show
plt.xticks(fontsize = 25,rotation = 65)
plt.yticks(fontsize = 25)
plt.xlabel("Running style",fontsize = 25)
plt.ylabel("Number of players",fontsize = 25)
plt.title("Number of players based on running style",fontsize = 40)
print(j)
# Out:
# Default Stride Awkward           539
# Default Stride Loose             483
# Default                          366
# Long Stride Loose                272
# Long Stride Default              158
# Short Stride Loose               140
# Long Stride Awkward              110
# Short Stride Default              87
# Default Stride High and Tight     45
# Long Stride High and Tight        44
# Short Stride High and Tight       21
# Default Stride Bread Loaf         11
# Short Stride Awkward              10
# Short Stride Bread Loaf            5
# Long Stride Bread Loaf             2
# Name: Running Style, dtype: int64

# %%
k = df[' Total Salary ']
kv = k.value_counts()
print(kv)
# Out:
#  $750,000.00        136
#  $2,540,000.00      104
#  $2,460,000.00       93
#  $590,000.00         79
#  $660,000.00         65
#                    ...
#  $2,380,000.00        1
#  $2,805,710.00        1
#  $7,696,063.00        1
#  $79,000,000.00       1
#  $7,750,000.00        1
# Name:  Total Salary , Length: 822, dtype: int64

# %%
ordf = df[df['Overall Rating']== 99]
ordf
# Out:
#        Team            Full Name  Overall Rating Position  Age  Speed  \
# 0      Rams         Aaron Donald              99       RE   29     82
# 1  Patriots      Stephon Gilmore              99       CB   29     92
# 2  Panthers  Christian McCaffrey              99       HB   24     92
# 3    Chiefs      Patrick Mahomes              99       QB   24     81
# 4    Saints       Michael Thomas              99       WR   27     89
#
#    Acceleration  Awareness  Agility  Strength  ...  Jersey Number  \
# 0            90         99       86        99  ...             99
# 1            94         99       94        70  ...             24
# 2            93         97       97        72  ...             22
# 3            87         97       88        69  ...             15
# 4            92         99       92        77  ...             13
#
#        Total Salary     Signing Bonus          Archetype  \
# 0   $101,892,000.00    $40,000,000.00     DE_PowerRusher
# ...
